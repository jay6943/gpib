# %%
import numpy as np
import pandas as pd

data = {}

data['X ($\mu$m)'] = np.linspace(1, 10, 10)
data['Y ($\mu$m)'] = data['X ($\mu$m)'] * data['X ($\mu$m)']

df = pd.DataFrame(data)
df.to_csv('D:/python/dat.csv', index=False)

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('D:/python/dat.csv')

plt.plot(df.set_index(df.columns[0]), 'o-')
plt.xlabel(df.columns[0])
plt.ylabel(df.columns[1])
plt.grid()
plt.show()
